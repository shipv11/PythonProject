# %%
# We're going to analyse the dataset salaries using pandas

# %%
import pandas as pd

# %%
# the file to be uploaded should be in the same folder as the jupyter notebook

# %%
df = pd.read_csv("Salaries.csv")                 #loading the file
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.size         # shows the number of entries in the dataframe
# Out:
# 468

# %%
df.shape         #shows the number of rows and columns respectively
# Out:
# (78, 6)

# %%
print("Rows =", df.shape[0])    #printing the number of rows
# Out:
# Rows = 78

# %%
df.head(4)         # gives us the top 4 rows
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205

# %%
df.tail()        # gives us the last 5 rows
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df[["rank"]]         # pulling only the column rank
# Out:
#          rank
# 0        Prof
# 1        Prof
# 2        Prof
# 3        Prof
# 4        Prof
# ..        ...
# 73       Prof
# 74  AssocProf
# 75       Prof
# 76       Prof
# 77       Prof
#
# [78 rows x 1 columns]

# %%
df[["rank", "salary"]]         # pulling 2 columns simultaneously
# Out:
#          rank  salary
# 0        Prof  186960
# 1        Prof   93000
# 2        Prof  110515
# 3        Prof  131205
# 4        Prof  104800
# ..        ...     ...
# 73       Prof  105450
# 74  AssocProf  104542
# 75       Prof  124312
# 76       Prof  109954
# 77       Prof  109646
#
# [78 rows x 2 columns]

# %%
df[["rank", "salary"]].head(7)
# Out:
#         rank  salary
# 0       Prof  186960
# 1       Prof   93000
# 2       Prof  110515
# 3       Prof  131205
# 4       Prof  104800
# 5       Prof  122400
# 6  AssocProf   81285

# %%
df.describe()           # gives us information about all the numerical columns
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.info()                # gives us information about all the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df["rank"].value_counts()             # tells us the number of unique values in a column
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df[df["rank"] == "Prof"]          # filtering the dataframe for rows with rank professor
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 1   Prof          A   12        6    Male   93000
# 2   Prof          A   23       20    Male  110515
# 3   Prof          A   40       31    Male  131205
# 4   Prof          B   20       18    Male  104800
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 8   Prof          A   29       19    Male   94350
# 9   Prof          A   51       51    Male   57800
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 18  Prof          A   19        7    Male  107300
# 19  Prof          A   29       27    Male  150500
# 21  Prof          A   33       30    Male  103106
# 24  Prof          A   30       23    Male   91100
# ...

# %%
df[df["rank"] == "Prof"].head(8)
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800
# 5  Prof          A   20       20  Male  122400
# 7  Prof          A   18       18  Male  126300
# 8  Prof          A   29       19  Male   94350

# %%
df[(df["rank"] == "Prof") & (df["discipline"]=="A") & (df["salary"]>= 100000)]           # using multiple filters
# Out:
#     rank discipline  phd  service     sex  salary
# 2   Prof          A   23       20    Male  110515
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 18  Prof          A   19        7    Male  107300
# 19  Prof          A   29       27    Male  150500
# 21  Prof          A   33       30    Male  103106
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 32  Prof          A   27       19    Male  103275
# 37  Prof          A   20        8    Male  102000
# 40  Prof          A   39       36  Female  137000
# 52  Prof          A   12        0  Female  105000
# 65  Prof          A   36       19  Female  117555
# 69  Prof          A   28        7  Female  116450
# 76  Prof          A   28       14  Female  109954
# 77  Prof          A   23       15  Female  109646

# %%
df.sort_values(by= "salary", ascending = False).head(10)     # getting the top 10 rows with highest salary
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 72  Prof          B   24       15  Female  161101
# 27  Prof          A   45       43    Male  155865
# 31  Prof          B   22       21    Male  155750
# 14  Prof          B   25       19    Male  153750
# 44  Prof          B   23       19  Female  151768
# 19  Prof          A   29       27    Male  150500
# 15  Prof          B   17        3    Male  150480
# 26  Prof          A   38       19    Male  148750

# %%
df.sort_values(by= ["rank", "discipline"]).head(10)         # sorting by two columns
# Out:
#          rank discipline  phd  service     sex  salary
# 6   AssocProf          A   20       17    Male   81285
# 41  AssocProf          A   13        8  Female   74830
# 54  AssocProf          A   25       22  Female   62884
# 56  AssocProf          A   10        8  Female   77500
# 64  AssocProf          A   26       24  Female   73300
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 47  AssocProf          B   11       11  Female  103613
# 59  AssocProf          B   12       10  Female  103994
# 61  AssocProf          B   13       10  Female  103750

# %%
df.groupby("rank").mean()             # shows the average values of all numeric columns grouped by rank
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby("rank")[["salary"]].mean()   # shows the average salary of different ranks
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df.groupby(["rank","discipline"])[["salary"]].mean()    # shows the average salary by different ranks and disciplines
# Out:
#                              salary
# rank      discipline
# AssocProf A            73959.800000
#           B           102927.750000
# AsstProf  A            74450.000000
#           B            86390.272727
# Prof      A           111935.695652
#           B           135313.913043

# %% [markdown]
# #### matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# bar chart showing rank wise highest salary using matplotlib

plt.bar(df["rank"], df["salary"], width= 0.5, color= "green")
plt.xlabel("Rank")
plt.ylabel("Salary")
plt.title("Rank wise salary")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# bar chart showing rank wise average salary using seaborn

sns.barplot(x="rank", y="salary", data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# bar chart showing rank wise average salary using matplotlib

df.groupby("rank")[["salary"]].mean().sort_values(by="salary", ascending=False).plot(kind="bar")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# scatterplot showing the relationship between salary and phd for different ranks

sns.scatterplot(x="phd",y="salary",data=df,hue="rank")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Pairplot showing the relationship between different numeric columns

sns.pairplot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Boxplot showing the distribution of salary

plt.boxplot(df[["salary"]])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df[["salary"]].skew()          # finding the skewness of salary
# Out:
# salary    0.452103
# dtype: float64
